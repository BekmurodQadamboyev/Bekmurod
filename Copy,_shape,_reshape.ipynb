# %% [markdown]
# <a href="https://colab.research.google.com/github/BekmurodQadamboyev/Bekmurod/blob/main/Copy%2C_shape%2C_reshape.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1-masala
#
# Massiv yarat: [1, 2, 3, 4] va uning shape qiymatini chiqar.

# %%
import numpy as np

# %% [markdown]
# 2-masala
#
# np.array([[1,2,3],[4,5,6]]) massivining o‘lchamini (shape) top.

# %%
arr = np.array

# %% [markdown]
# 3-masala
#
# np.arange(10) massivini yarat va uning shape ni aniqlang.

# %% [markdown]
# 4-masala
#
# 1D massivni ([1,2,3,4,5,6]) 2x3 shaklga (reshape) o‘zgartir.

# %% [markdown]
# 5-masala
#
# np.arange(8) massivini 4x2 shaklga o‘zgartir.

# %% [markdown]
# 6-masala
#
# 2x3 massivni 1D massivga (reshape) qaytar.

# %% [markdown]
# 7-masala
#
# Massivdan nusxa (copy) ol va asl massivni o‘zgartirganda nusxa o‘zgarmasligini tekshir.

# %% [markdown]
# 8-masala
#
# np.array([10,20,30]) dan copy yarat va copy ustida qiymatni o‘zgartir.

# %% [markdown]
# 9-masala
#
# Massiv yarat va uning shape ni (3, 2) ga o‘zgartir.

# %% [markdown]
# 10-masala
#
# np.arange(12) massivini 3 o‘lchamli shaklga (2x2x3) o‘zgartir.

# %% [markdown]
# 11-masala
#
# Massivning shape ni o‘zgartirmasdan uning nusxasini (copy) yarat.

# %% [markdown]
# 12-masala
#
# np.ones((2,3)) massivining shape ni chiqar.

# %% [markdown]
# 13-masala
#
# Massivni (6,) shaklidan (2,3) shaklga o‘tkaz.

# %% [markdown]
# 14-masala
#
# reshape(-1, 2) yordamida massivni qayta shakllantir.

# %% [markdown]
# 15-masala
#
# Massivdan copy ol va ikkala massivni solishtir (== bilan).

# %% [markdown]
# # dasr_3

# %% [markdown]
# 1 dan 10 gacha bo‘lgan tasodifiy bitta sonni chiqaruvchi dastur yozing.

# %%
son1 = random.randint(1, 10)
son1
# Out:
# 4

# %% [markdown]
# 5 ta elementdan iborat, 0 dan 50 gacha tasodifiy sonlardan iborat massiv yarating.

# %%
import numpy as np

random_array = np.random.randint(0, 51, size=5)
print(random_array)
# Out:
# [28 42 20 10  0]

# %% [markdown]
# 10 ta tasodifiy son (1–100 oralig‘ida) hosil qiling va ularning yig‘indisini toping.

# %%
import numpy as np
sonlar1 = np.random.randint(1, 101, size=10)
sonlar2 = sonlar1.sum()

print("Tasodifiy sonlar:", sonlar1)
print("Raqamlar yig'indisi:", sonlar2)
# Out:
# Tasodifiy sonlar: [98 39 63 31 54 88 33  5 55 43]
# Raqamlar yig'indisi: 509

# %% [markdown]
# 3x3 o‘lchamli matritsa yarating (elementlari 0–9 oralig‘ida bo‘lsin).

# %%
import numpy as np

sonlar_3x3 = np.random.randint(0, 10, size=(3, 3))
print(sonlar_3x3)
# Out:
# [[8 4 0]
#  [8 0 7]
#  [8 3 3]]

# %% [markdown]
# 20 ta tasodifiy son ichidan faqat juft sonlarni ajratib chiqaring.

# %%
import numpy as np
kop_sonlar = np.random.randint(1, 101, size=20)
Juft_sonlar = random_numbers[random_numbers % 2 == 0]

print("Tasodifiy sonlar:", kop_sonlar)
print("Sonlar yig'indisi:", Juft_sonlar)
# Out:
# Tasodifiy sonlar: [17 25 10 49 77 37 74 69  8  4 41 37 95 33 56 81 47 71 98 17]
# Sonlar yig'indisi: [48 14 82 94 64 58 54  6 62]

# %% [markdown]
# 0 va 1 oralig‘ida bitta tasodifiy haqiqiy son chiqaring.

# %%
import numpy as np

random_float = np.random.rant()
print(random_float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2675/1071673931.py in <cell line: 0>()
#       1 import numpy as np
#       2
# ----> 3 random_float = np.random.rant()
#       4 print(random_float)
#
# AttributeError: module 'numpy.random' has no attribute 'rant'
